# %% [markdown]
# # Reading a CSV as a Pandas DataFrame

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas and pathlib
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
csv_path = Path('../Resources/people.csv')

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame

# %%
# Use the file path to read the CSV into a DataFrame
csv_df = pd.read_csv(csv_path)

# %% [markdown]
# ### 4. Display a Few Rows of the DataFrame

# %%
# Use the `head` function to display a few rows of the top of the DataFrame
csv_df.tail(10)
# Out:
#          id first_name  last_name                      email  gender  \
# 990   991.0     Julian  Hampshire    jhampshireri@disqus.com    Male
# 991   992.0     Davine    Glossop   dglossoprj@goodreads.com  Female
# 992   993.0   Dorothea       Rugg   druggrk@miitbeian.gov.cn  Female
# 993   994.0    Damaris  Griffitts  dgriffittsrl@mapquest.com  Female
# 994   995.0       Iggy     Jeacop      ijeacoprm@4shared.com    Male
# 995   996.0       Meta   Crumpton         mcrumptonrn@qq.com  Female
# 996   997.0      Gunar    Gilford       ggilfordro@yandex.ru    Male
# 997   998.0   Lucretia    Gurling           lgurlingrp@de.vu  Female
# 998   999.0     Andrew       Yang       ayang@codedrills.com    Male
# 999  1000.0     Andrew       Yang       ayang@codedrills.com    Male
#
#                                    uni_grad              job_title    Income
# 990              Johnson & Wales University      Chemical Engineer   79024.0
# 991     Université René Descartes (Paris V)     VP Quality Control   50599.0
# 992  Universidad Politécnica de El Salvador           VP Marketing  114586.0
# 993                  The College of Wooster          Senior Editor  113339.0
# 994                 University of Greenwich        Sales Associate   82726.0
# 995    ECAM - Institut Supérieur Industriel       Registered Nurse   57060.0
# 996                       Smolny University      Marketing Manager   76109.0
# 997               Institut Teknologi Telkom  Software Engineer III   92115.0
# 998   Rutgers University School of Business    Curriculum Engineer   60000.0
# 999   Rutgers University School of Business    Curriculum Engineer   60000.0

# %% [markdown]
# ### 5. Generate Summary Statistics on the DataFrame

# %%
# Use the `include` parameter set to 'all' to include all columns (and datatypes)
csv_df.describe(include='all')
# Out:
#                  id first_name last_name                 email gender  \
# count    996.000000        993       990                   992    998
# unique          NaN        914       974                   991      2
# top             NaN     Israel      Yang  ayang@codedrills.com   Male
# freq            NaN          3         2                     2    508
# mean     500.213855        NaN       NaN                   NaN    NaN
# std      289.172174        NaN       NaN                   NaN    NaN
# min        1.000000        NaN       NaN                   NaN    NaN
# 25%      249.750000        NaN       NaN                   NaN    NaN
# 50%      500.000000        NaN       NaN                   NaN    NaN
# 75%      750.250000        NaN       NaN                   NaN    NaN
# max     1000.000000        NaN       NaN                   NaN    NaN
#
#                                                  uni_grad  \
# count                                                 991
# unique                                                939
# top     Université des Sciences et de la Technologie d...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                     job_title         Income
# count                     998     998.000000
# unique                    183            NaN
# top     Chief Design Engineer            NaN
# freq                       16            NaN
# mean                      NaN   84691.693387
# std                       NaN   20185.664319
# min                       NaN   50013.000000
# 25%                       NaN   67353.000000
# 50%                       NaN   84296.000000
# 75%                       NaN  102374.750000
# max                       NaN  119987.000000
