# %% [markdown]
# # Spring Cleaning!

# %% [markdown]
# Harold's stock data is a mess! Help him clean up his data before the auditors arrive!

# %%
# Import Libraries
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Load CSV data into Pandas using `read_csv`

# %%
stockfile = Path("../../Resources/stock_data.csv")
stock_df = pd.read_csv(stockfile)
stock_df.head()
# Out:
#   symbol                 name                  sector    price  \
# 0    MMM           3M Company             Industrials  $222.89
# 1    AOS      A.O. Smith Corp             Industrials      NaN
# 2    ABT  Abbott Laboratories             Health Care    56.27
# 3   ABBV          AbbVie Inc.             Health Care   108.48
# 4   ATVI  Activision Blizzard  Information Technology    65.83
#
#    price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0               24.31        2.332862              $7.92      259.770
# 1                 NaN             NaN                NaN          NaN
# 2               22.51        1.908982               0.26       64.600
# 3               19.41        2.499560               3.29      125.860
# 4                 NaN        0.431903               1.28       74.945
#
#    52_week_high    market_cap        ebitda  price_per_sales  price_per_book  \
# 0        175.49  1.387211e+11  9.048000e+09         4.390271           11.34
# ...

# %% [markdown]
# ### Identify the number of rows and columns (shape) in the DataFrame.

# %%
stock_df.shape
# Out:
# (504, 14)

# %% [markdown]
# ### Generate a sample of the data to visually ensure data has been loaded in correctly.

# %%
stock_df.sample(3)
# Out:
#     symbol                            name       sector  price  \
# 93     CBG                      CBRE Group  Real Estate  41.92
# 79     BMY            Bristol-Myers Squibb  Health Care  62.69
# 261    JCI  Johnson Controls International  Industrials  36.55
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 93                15.82        0.000000               1.69        46.60
# 79                20.83        2.554686               2.65        66.10
# 261               14.00        2.765957               1.71        44.37
#
#      52_week_high    market_cap        ebitda  price_per_sales  \
# 93          30.43  1.444059e+10  1.652961e+09         1.462232
# 79          51.12  1.025065e+11  5.170000e+09         6.503231
# 261         34.51  3.482222e+10  4.295000e+09         1.141534
#
#      price_per_book                                        sec_filings
# 93             3.74  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ...

# %% [markdown]
# ### Identify the number of records in the DataFrame, and compare it with the number of rows in the original file.

# %%
stock_df.count()
# Out:
# symbol                504
# name                  502
# sector                501
# price                 500
# price_per_earnings    497
# dividend_yield        499
# earnings_per_share    498
# 52_week_low           500
# 52_week_high          500
# market_cap            500
# ebitda                492
# price_per_sales       500
# price_per_book        492
# sec_filings           500
# dtype: int64

# %% [markdown]
# ### Identify nulls records

# %%
stock_df.isnull().mean() * 100
# Out:
# symbol                0.000000
# name                  0.396825
# sector                0.595238
# price                 0.793651
# price_per_earnings    1.388889
# dividend_yield        0.992063
# earnings_per_share    1.190476
# 52_week_low           0.793651
# 52_week_high          0.793651
# market_cap            0.793651
# ebitda                2.380952
# price_per_sales       0.793651
# price_per_book        2.380952
# sec_filings           0.793651
# dtype: float64

# %%
stock_df.isnull().sum()
# Out:
# symbol                 0
# name                   2
# sector                 3
# price                  4
# price_per_earnings     7
# dividend_yield         5
# earnings_per_share     6
# 52_week_low            4
# 52_week_high           4
# market_cap             4
# ebitda                12
# price_per_sales        4
# price_per_book        12
# sec_filings            4
# dtype: int64

# %% [markdown]
# ### Drop Null Records

# %%
stock_df_clean = stock_df.dropna()
stock_df_clean
# Out:
#     symbol                    name                  sector    price  \
# 0      MMM              3M Company             Industrials  $222.89
# 2      ABT     Abbott Laboratories             Health Care    56.27
# 3     ABBV             AbbVie Inc.             Health Care   108.48
# 5      AYI       Acuity Brands Inc             Industrials   108.48
# 6     ADBE       Adobe Systems Inc  Information Technology   185.16
# ..     ...                     ...                     ...      ...
# 499    XYL              Xylem Inc.             Industrials    70.24
# 500    YUM         Yum! Brands Inc  Consumer Discretionary     76.3
# 501    ZBH  Zimmer Biomet Holdings             Health Care   115.53
# 502   ZION           Zions Bancorp              Financials    50.71
# 503    ZTS                  Zoetis             Health Care    71.51
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0                 24.31        2.332862              $7.92       259.77
# ...

# %% [markdown]
# ### Validate nulls have been dropped

# %%
stock_df_clean.isnull().mean() * 100
# Out:
# symbol                0.0
# name                  0.0
# sector                0.0
# price                 0.0
# price_per_earnings    0.0
# dividend_yield        0.0
# earnings_per_share    0.0
# 52_week_low           0.0
# 52_week_high          0.0
# market_cap            0.0
# ebitda                0.0
# price_per_sales       0.0
# price_per_book        0.0
# sec_filings           0.0
# dtype: float64

# %% [markdown]
# ### Default null `ebitda` values to 0. Then, validate no records are null for ebitda.

# %%
stock_df.loc[:, ['ebitda']] = stock_df.loc[:, ['ebitda']].fillna(0).copy()
stock_df[['ebitda']].isnull().sum()
# Out:
# ebitda    0
# dtype: int64

# %% [markdown]
# ### Drop Duplicates
